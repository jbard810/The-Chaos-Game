# %%
import random
import math
import matplotlib.pyplot as plt


sideLength = 1
n = 99999
x0,y0 = 0.5,0.5
initPoint = (x0,y0)

vertices = {1:(0,0), 2:(sideLength,0), 3:(0.5*sideLength,0.5*math.sqrt(3)*sideLength)}

def chaosGameGeneration(n, initPoint, sideLength):
  vertices = {1:(0,0), 2:(sideLength,0), 3:(0.5*sideLength,0.5*math.sqrt(3)*sideLength)}
  rand_vert_selection = [random.randint(1,3) for i in range(n)]
  points = []
  points.append(initPoint)
  xi,yi = initPoint[0],initPoint[1]

  for i in range(n):
    vertPoint = vertices[rand_vert_selection[i]]
    x,y = vertPoint[0],vertPoint[1]
    xi = (xi+x)/2
    yi = (yi+y)/2
    points.append((xi,yi))

  return points

points = chaosGameGeneration(n, initPoint, sideLength)
xs = [point[0] for point in points]
ys = [point[1] for point in points]


fig = plt.plot([0,0.5*sideLength,sideLength],[0,0.5*math.sqrt(3)*sideLength,0],color='blue')
fig = plt.plot([0,sideLength],[0,0],color='blue')
fig = plt.scatter(xs,ys,s=0.5)

image_format = 'svg' # e.g .png, .svg, etc.
image_name = 'myimage.svg'

#plt.savefig(image_name, format=image_format, dpi=999)

# %%
import random
import math
import matplotlib.pyplot as plt


sideLength = 1
n = 10
x0,y0 = 0.5,0.5
initPoint = (x0,y0)

vertices = {1:(0.5*math.sqrt(2)*sideLength,0),
            2:(0,0.5*math.sqrt(2)*sideLength),
            3:(math.sqrt(2)*sideLength,0.5*math.sqrt(2)*sideLength),
            4: (math.sqrt(2)*sideLength,0.5*math.sqrt(2)*sideLength)}

def chaosGameGeneration(n, initPoint, sideLength):
  vertices = {1:(0,0), 2:(sideLength,0), 3:(0.5*sideLength,0.5*math.sqrt(3)*sideLength)}
  rand_vert_selection = [random.randint(1,3) for i in range(n)]
  points = []
  points.append(initPoint)
  xi,yi = initPoint[0],initPoint[1]

  for i in range(n):
    vertPoint = vertices[rand_vert_selection[i]]
    x,y = vertPoint[0],vertPoint[1]
    xi = (xi+x)/2
    yi = (yi+y)/2
    points.append((xi,yi))

  return points

points = chaosGameGeneration(n, initPoint, sideLength)
xs = [point[0] for point in points]
ys = [point[1] for point in points]


fig = plt.plot([0,0.5*sideLength,sideLength],[0,0.5*math.sqrt(3)*sideLength,0],color='blue')
fig = plt.plot([0,sideLength],[0,0],color='blue')
fig = plt.scatter(xs,ys,s=0.4)
